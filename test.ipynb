# %%
import pandas as pd
import os

# %%
folder = './sst/data/'

# %%
file_names = os.listdir('./sst/data/')
file_names
# Out:
# ['Plat 1A S1.csv', 'Plat 1S S2.csv', 'Plat 2A S1.csv', 'Plat 2A S2.csv']

# %%
folder + file_names[2]
# Out:
# './sst/data/Plat 2A S1.csv'

# %%
df1 = pd.read_csv("./sst/data/Plat 2A S1.csv")
df1
# Out:
#                         Sample Name,Plat 2A S1-EVENT
# 0                     Method Name,2A_S1_6mins_QC.amx
# 1  Name,RT [min],Area,Height,USP Resolution,Taili...
# 2                  QC1,0.33,74.2294,69.563,,1.1,PASS
# 3           QC2,0.63,109.3673,188.465,14.30,1.3,PASS
# 4            QC3,1.19,95.2262,120.295,31.60,1.1,PASS
# 5           QC4,3.09,228.9143,229.747,83.23,1.0,PASS
# 6                                     Numb,4.00,,,,,
# 7                                    All peaks found

# %%
df1.columns = df1.iloc[1]

# %%
df1.drop([0, 1, 5, 6], axis = 0, inplace = True)

# %%
df1
# Out:
# 1 Name RT [min]     Area   Height USP Resolution Tailing   SST
# 2  QC1     0.41  75.2962   69.708            NaN     1.3  PASS
# 3  QC3     1.26  95.8244  120.729          34.52     1.3  PASS
# 4  QC4     3.18   226.64  248.226          87.11     1.2  PASS

# %%
df1.insert(0, 
        column = 'File Name',
        value = file_names[0].split('.csv')[0])

# %%
df1
# Out:
# 1   File Name Name RT [min]     Area   Height USP Resolution Tailing   SST
# 2  Plat 1A S1  QC1     0.41  75.2962   69.708            NaN     1.3  PASS
# 3  Plat 1A S1  QC3     1.26  95.8244  120.729          34.52     1.3  PASS
# 4  Plat 1A S1  QC4     3.18   226.64  248.226          87.11     1.2  PASS

# %%
def clean_dataframe(folder: str, files: list):
    all_df = []
    for i in range(len(files)):
        with open(folder + files[i], 'r') as file:
            csv_reader = csv.reader(file)

            clean_data_dict = {}
            column_name = {}
            data_columns_len = 0
            for idx, row in enumerate(csv_reader):
                if len(row) != 0 and row[0] == 'Name':
                    column_name['names'] = row
                    data_columns_len = len(row)

                elif len(row) != 0 and len(row) == data_columns_len:
                    if row[0].split('C')[0] == 'Q':
                        clean_data_dict[idx] = row

        df = pd.DataFrame.from_dict(clean_data_dict, orient ='index', columns = column_name['names']).reset_index(drop = True)
        df.insert(0, 
        column = 'File Name',
        value = file_names[i].split('.csv')[0])

        all_df.append(df)
        
    return all_df

# %%
all_df = clean_dataframe(folder, file_names)

# %%
all_df
# Out:
# [    File Name Name RT [min]     Area   Height USP Resolution Tailing   SST
#  0  Plat 1A S1  QC1     0.41  75.2962   69.708                    1.3  PASS
#  1  Plat 1A S1  QC3     1.26  95.8244  120.729          34.52     1.3  PASS
#  2  Plat 1A S1  QC4     3.18   226.64  248.226          87.11     1.2  PASS,
#      File Name Name RT [min]     Area   Height USP Resolution Tailing   SST
#  0  Plat 1S S2  QC1     0.43  73.0775   64.666                    1.2  PASS
#  1  Plat 1S S2  QC2     0.74  107.423   182.44          13.71     1.3  PASS
#  2  Plat 1S S2  QC4     3.19  225.023  245.971          90.17     1.1  PASS,
#      File Name Name RT [min]      Area   Height USP Resolution Tailing   SST
#  0  Plat 2A S1  QC1     0.33   74.2294   69.563                    1.1  PASS
#  1  Plat 2A S1  QC2     0.63  109.3673  188.465          14.30     1.3  PASS
#  2  Plat 2A S1  QC3     1.19   95.2262  120.295          31.60     1.1  PASS
#  3  Plat 2A S1  QC4     3.09  228.9143  229.747          83.23     1.0  PASS,
#      File Name Name RT [min]      Area   Height USP Resolution Tailing   SST
#  0  Plat 2A S2  QC1     0.34   75.5446   69.333                    1.1  PASS
#  1  Plat 2A S2  QC2     0.65  138.9084  193.495          14.14     1.4  PASS
#  2  Plat 2A S2  QC3     1.04  100.1758  115.899          21.66     1.0  PASS
#  3  Plat 2A S2  QC4     3.10  242.7297  231.590          87.68     1.0  PASS]

# %%
merged_df = pd.DataFrame()
# Merge DataFrames
for df in all_df:
    merged_df = pd.concat([merged_df, df], ignore_index=True)

# %%
merged_df
# Out:
#      File Name Name RT [min]      Area   Height USP Resolution Tailing   SST
# 0   Plat 1A S1  QC1     0.41   75.2962   69.708                    1.3  PASS
# 1   Plat 1A S1  QC3     1.26   95.8244  120.729          34.52     1.3  PASS
# 2   Plat 1A S1  QC4     3.18    226.64  248.226          87.11     1.2  PASS
# 3   Plat 1S S2  QC1     0.43   73.0775   64.666                    1.2  PASS
# 4   Plat 1S S2  QC2     0.74   107.423   182.44          13.71     1.3  PASS
# 5   Plat 1S S2  QC4     3.19   225.023  245.971          90.17     1.1  PASS
# 6   Plat 2A S1  QC1     0.33   74.2294   69.563                    1.1  PASS
# 7   Plat 2A S1  QC2     0.63  109.3673  188.465          14.30     1.3  PASS
# 8   Plat 2A S1  QC3     1.19   95.2262  120.295          31.60     1.1  PASS
# 9   Plat 2A S1  QC4     3.09  228.9143  229.747          83.23     1.0  PASS
# 10  Plat 2A S2  QC1     0.34   75.5446   69.333                    1.1  PASS
# 11  Plat 2A S2  QC2     0.65  138.9084  193.495          14.14     1.4  PASS
# 12  Plat 2A S2  QC3     1.04  100.1758  115.899          21.66     1.0  PASS
# 13  Plat 2A S2  QC4     3.10  242.7297  231.590          87.68     1.0  PASS

# %%
import streamlit as st
import os
import pandas as pd


df = pd.read_csv('./sst/data/Plat 1A S1.csv')
df
# Out:
#            Sample Name    Plat 1A S1-EVENT Unnamed: 2 Unnamed: 3  \
# 0          Method Name  1A_S1_6mins_QC.amx        NaN        NaN
# 1                 Name            RT [min]       Area     Height
# 2                  QC1                0.41    75.2962     69.708
# 3                  QC3                1.26    95.8244    120.729
# 4                  QC4                3.18     226.64    248.226
# 5                 Numb                   3        NaN        NaN
# 6  All peaks not found                 NaN        NaN        NaN
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0             NaN        NaN        NaN
# 1  USP Resolution    Tailing        SST
# 2             NaN        1.3       PASS
# 3           34.52        1.3       PASS
# 4           87.11        1.2       PASS
# 5             NaN        NaN        NaN
# 6             NaN        NaN        NaN

# %%
import requests

# %%
url = "https://portaointeligente2.azurewebsites.net/api/agilento/sst-file/?format=json"
token = "dd11c4e81c14922d97cdf1913b0e022b5226a33e"

# %%
headers = {
    'Authorization': f'Token {token}',
    'Content-Type': 'application/json',
}

# %%
response = requests.get(url, headers=headers)

# %%
# Check the response status code
if response.status_code == 200:
    # The request was successful, and you can access the response content
    print(response.json())
elif response.status_code == 401:
    # Handle the unauthorized error
    print("Authentication failed. Check your token.")
else:
    # Handle other errors
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# [{'id': 1, 'date': '2023-10-16', 'hour': '11:55:58', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S2-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S2_QC.amx', 'file_name': 'Plat 1A S2-EVENT_2023-10-16 12-57-01+01-00.csv', 'name': 'QC1', 'rt_min': '0.42', 'area': '210.7878', 'height': '171.4730', 'usp_resolution': None, 'tailing': '1.50', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-10-16T11:55:58.227082Z'}, {'id': 2, 'date': '2023-10-16', 'hour': '11:55:58', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S2-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S2_QC.amx', 'file_name': 'Plat 1A S2-EVENT_2023-10-16 12-57-01+01-00.csv', 'name': 'QC2', 'rt_min': '0.71', 'area': '352.3137', 'height': '479.1820', 'usp_resolution': '11.6100', 'tailing': '1.40', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-10-16T11:55:58.233478Z'}, {'id': 3, 'date': '2023-10-16', 'hour': '11:55:58', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S2-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S2_QC.amx', 'file_name': 'Plat 1A S2-EVENT_2023-10-16 12-57-01+01-00.csv', 'name': 'QC3', 'rt_min': '1.00', 'area': '285.7858', 'height': '288.9300', 'usp_resolution': '13.4400', 'tailing': '0.90', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-10-16T11:55:58.236324Z'}, {'id': 4, 'date': '2023-10-16', 'hour': '11:55:58', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S2-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S2_QC.amx', 'file_name': 'Plat 1A S2-EVENT_2023-10-16 12-57-01+01-00.csv', 'name': 'QC4', 'rt_min': '3.20', 'area': '162.1239', 'height': '150.1750', 'usp_resolution': '82.6600', 'tailing': '1.30', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-10-16T11:55:58.239334Z'}, {'id': 1226, 'date': '2023-11-15', 'hour': '06:25:56', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S1-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S1_QC.amx', 'file_name': 'Plat 1A S1-EVENT 2023-11-15 06-27-59+00-00.csv', 'name': 'QC1', 'rt_min': '0.38', 'area': '67.3139', 'height': '57.1430', 'usp_resolution': None, 'tailing': '1.40', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-11-15T06:25:56.861736Z'}, {'id': 1227, 'date': '2023-11-15', 'hour': '06:25:56', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S1-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S1_QC.amx', 'file_name': 'Plat 1A S1-EVENT 2023-11-15 06-27-59+00-00.csv', 'name': 'QC2', 'rt_min': '0.67', 'area': '110.8552', 'height': '188.5550', 'usp_resolution': '1.0800', 'tailing': '1.30', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-11-15T06:25:56.866823Z'}, {'id': 1228, 'date': '2023-11-15', 'hour': '06:25:56', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S1-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S1_QC.amx', 'file_name': 'Plat 1A S1-EVENT 2023-11-15 06-27-59+00-00.csv', 'name': 'QC3', 'rt_min': '1.25', 'area': '90.5430', 'height': '111.9970', 'usp_resolution': '32.5600', 'tailing': '1.20', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-11-15T06:25:56.876374Z'}, {'id': 1229, 'date': '2023-11-15', 'hour': '06:25:56', 'hostname': 'DESKTOP-QFL5IDO', 'ip_address': '10.0.4.15', 'sample_name': 'Plat 1A S1-EVENT', 'method_name': 'Plat1A_PoroC18_50mm_S1_QC.amx', 'file_name': 'Plat 1A S1-EVENT 2023-11-15 06-27-59+00-00.csv', 'name': 'QC4', 'rt_min': '3.15', 'area': '215.7776', 'height': '229.5690', 'usp_resolution': '33.5900', 'tailing': '1.10', 'sst': 'PASS', 'numb': '4.00', 'comment': "['All peaks found']", 'created_at': '2023-11-15T06:25:56.880782Z'}, {'id': 1234, 'date': '2023-11-23', 'hour': '17:44:01', 'hostname': 'DESKTOP-REMA8 ...

# %%
import pandas as pd

# %%
data = response.json()

# %%
df = pd.DataFrame(data)
df.to_csv('api_data.csv')
